# %%
# data science libraies
# data analyzing and is a numerical plotting library
# metaplotlib
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])

# %%
plt.ylabel('some numbers')
# Out:
# Text(0, 0.5, 'some numbers')

# %%
plt.show()

# %%
plt.plot([1,2,3,4],[1,4,9,16])

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
import requests

# %%
r = requests.get('https://api.github.com/user', auth=('user', 'pass'))

# %%
r.status_code
# Out:
# 401

# %%
r.headers['content-type']
'application/json; charset=utf8'
# Out:
# 'application/json; charset=utf8'

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r.text
# Out:
# '{"message":"Requires authentication","documentation_url":"https://docs.github.com/rest/reference/users#get-the-authenticated-user"}'

# %%
r.json()
# Out:
# {'message': 'Requires authentication',
#  'documentation_url': 'https://docs.github.com/rest/reference/users#get-the-authenticated-user'}

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
r
# Out:
# <Response [200]>

# %%
r = requests.post('https://httpbin.org/post', data = {'key':'value'})

# %%
r
# Out:
# <Response [200]>

# %%
r = requests.put('https://httpbin.org/put', data = {'key':'value'})

# %%
r = requests.delete('https://httpbin.org/delete')

# %%
r = requests.head('https://httpbin.org/get')

# %%
r = requests.options('https://httpbin.org/get')

# %%
payload = {'key1': 'value1', 'key2': 'value2'}

# %%
r = requests.get('https://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2

# %%
payload = {'key1': 'value1', 'key2': ['value2', 'value3']}

# %%
 r = requests.get('https://httpbin.org/get', params=payload)

# %%
print(r.url)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2&key2=value3

# %%
r = requests.get('https://api.github.com/events')

# %%
r.text
# Out:
# '[{"id":"15035897074","type":"CreateEvent","actor":{"id":4200196,"login":"cragod","display_login":"cragod","gravatar_id":"","url":"https://api.github.com/users/cragod","avatar_url":"https://avatars.githubusercontent.com/u/4200196?"},"repo":{"id":244336061,"name":"cragod/CYWidgets","url":"https://api.github.com/repos/cragod/CYWidgets"},"payload":{"ref":"v0.4.17","ref_type":"tag","master_branch":"develop","description":"Widgets of quant app","pusher_type":"user"},"public":true,"created_at":"2021-02-02T14:39:49Z"},{"id":"15035897060","type":"IssueCommentEvent","actor":{"id":67855648,"login":"MayankUjawane","display_login":"MayankUjawane","gravatar_id":"","url":"https://api.github.com/users/MayankUjawane","avatar_url":"https://avatars.githubusercontent.com/u/67855648?"},"repo":{"id":276310559,"name":"priyalbhatewara123/SHE--Live-Without-Fear","url":"https://api.github.com/repos/priyalbhatewara123/SHE--Live-Without-Fear"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/priyalbhatewara123/SHE--Live-Without-Fear/issues/23","repository_url":"https://api.github.com/repos/priyalbhatewara123/SHE--Live-Without-Fear","labels_url":"https://api.github.com/repos/priyalbhatewara123/SHE--Live-Without-Fear/issues/23/labels{/name}","comments_url":"https://api.github.com/repos/priyalbhatewara123/SHE--Live-Without-Fear/issues/23/comments","events_url":"https://api.github.com/repos/priyalbhatewara123/SHE--Live-Without-Fear/issues/23/events","html_url":"https://github.com/priyalbhatewara123/SHE--Live-Without-Fear/pull/23","id":798959970,"node_id":"MDExOlB1bGxSZXF1ZXN0NTY1Njg1OTU0","number":23,"title":"issue of siren activity is resolved","user":{"login":"MayankUjawane","id":67855648,"node_id":"MDQ6VXNlcjY3ODU1NjQ4","avatar_url":"https://avatars.githubusercontent.com/u/67855648?v=4","gravatar_id":"","url":"https://api.github.com/users/MayankUjawane","html_url":"https://github.com/MayankUjawane","followers_url":"https://api.github.com/users/MayankUjawane/followers","following_url":"https://api.github.com/users/MayankUjawane/following{/other_user}","gists_url":"https://api.github.com/users/MayankUjawane/gists{/gist_id}","starred_url":"https://api.github.com/users/MayankUjawane/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/MayankUjawane/subscriptions","organizations_url":"https://api.github.com/users/MayankUjawane/orgs","repos_url":"https://api.github.com/users/MayankUjawane/repos","events_url":"https://api.github.com/users/MayankUjawane/events{/privacy}","received_events_url":"https://api.github.com/users/MayankUjawane/received_events","type":"User","site_admin":false},"labels":[],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":null,"comments":6,"created_at":"2021-02-02T06:01:04Z","updated_at":"2021-02-02T14:39:49Z","closed_at":null,"author_association":"CONTRIBUTOR","active_lock_reason":null,"pull_request":{"url":"https://api.github.com/repos/priyalbhatewara123/SHE--Live-Without-Fear/pulls/23","html_url":"https://github.com/priyalbhatewara123/SHE--Live-Without-Fear/pull/23","diff_url":"https://github.com/priyalbhatewara123/SHE--Live-Without-Fear/pull/23.diff","patch_url":"https://github.com/priyalbhatewara123/SHE--Live-Without-Fear/pull/23.patch"},"body":"I have solved the issue which was occured in the last pull request.","performed_via_github_app":null},"comment":{"url":"https://api.github.com/repos/priyalbhatewara123/SHE--Live-Without-Fear/issues/comments/771680598","html_url":"https://github.com/priyalbhatewara123/SHE--Live-Without-Fear/pull/23#issuecomment-771680598","issue_url":"https://api.github.com/repos/priyalbhatewara123/SHE--Live-Without-Fear/issues/23","id":771680598,"node_id":"MDEyOklzc3VlQ29tbWVudDc3MTY4MDU5OA==","user":{"login":"MayankUjawane","id":67855648,"node_id":"MDQ6VXNlcjY3ODU1NjQ4","avatar_url":"https://avatars.githubusercontent.com/u/67855648?v=4","gravatar_id":"","url":"https://api.github.com/users/MayankUjawane","html_url":"https://github.com/Maya ...

# %%
r.encoding
# Out:
# 'utf-8'

# %%
r = requests.get('https://api.github.com/events')

# %%
r.json()
# Out:
# [{'id': '15035915618',
#   'type': 'PushEvent',
#   'actor': {'id': 69316636,
#    'login': 'Abdulraheembashir043',
#    'display_login': 'Abdulraheembashir043',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Abdulraheembashir043',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69316636?'},
#   'repo': {'id': 334687132,
#    'name': 'Abdulraheembashir043/Number_System_Converter',
#    'url': 'https://api.github.com/repos/Abdulraheembashir043/Number_System_Converter'},
#   'payload': {'push_id': 6459679025,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'c2d284149cb3455beb646076f851654fb8104ada',
#    'before': '9a36a6b6ab4b6a6950766e94d2d53441562260cf',
#    'commits': [{'sha': 'c2d284149cb3455beb646076f851654fb8104ada',
#      'author': {'email': 'abdulraheembashir043@gmail.com',
#       'name': 'Abdulraheem Bashir'},
#      'message': 'Modifying footer',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Abdulraheembashir043/Number_System_Converter/commits/c2d284149cb3455beb646076f851654fb8104ada'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915604',
#   'type': 'PushEvent',
#   'actor': {'id': 77975337,
#    'login': 'ikitaichik',
#    'display_login': 'ikitaichik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ikitaichik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77975337?'},
#   'repo': {'id': 335265471,
#    'name': 'ikitaichik/Project1',
#    'url': 'https://api.github.com/repos/ikitaichik/Project1'},
#   'payload': {'push_id': 6459679006,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f833d2d1be2cc07dfd4f42a34726d95affcc510d',
#    'before': 'ceb84a5d1222ddb64886d00ef08f1e9eeb99f371',
#    'commits': [{'sha': 'f833d2d1be2cc07dfd4f42a34726d95affcc510d',
#      'author': {'email': '77975337+ikitaichik@users.noreply.github.com',
#       'name': 'ikitaichik'},
#      'message': 'Update jenkinsfile',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ikitaichik/Project1/commits/f833d2d1be2cc07dfd4f42a34726d95affcc510d'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915607',
#   'type': 'CreateEvent',
#   'actor': {'id': 67683030,
#    'login': 'IvanMetelkov',
#    'display_login': 'IvanMetelkov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/IvanMetelkov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67683030?'},
#   'repo': {'id': 335320052,
#    'name': 'IvanMetelkov/Pharmacy_app',
#    'url': 'https://api.github.com/repos/IvanMetelkov/Pharmacy_app'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915597',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 288713265,
#    'name': 'blombard/bitcoin-stats',
#    'url': 'https://api.github.com/repos/blombard/bitcoin-stats'},
#   'payload': {'push_id': 6459679003,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd432b4797afb242e95e712bb00f2132e10f919c8',
#    'before': '153e38d99a39bb95708743ca4fad6a77ebb3ca9f',
#    'commits': [{'sha': 'd432b4797afb242e95e712bb00f2132e10f919c8',
#      'author': {'email': 'actions@github.com', 'name': 'Author'},
#      'message': 'Update Bitcoin chart',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/blombard/bitcoin-stats/commits/d432b4797afb242e95e712bb00f2132e10f919c8'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915591',
#   'type': 'PushEvent',
#   'actor': {'id': 58213711,
#    'login': 'iplcdn',
#    'display_login': 'iplcdn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/iplcdn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/58213711?'},
#   'repo': {'id': 334918482,
#    'name': 'iplcdn/Actions-scripts',
#    'url': 'https://api.github.com/repos/iplcdn/Actions-scripts'},
#   'payload': {'push_id': 6459679004,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'f5e8bbe91a544a26f5179a40a906e4ea0a88df9a',
#    'before': '9ae11354a07ba81570c3eee071b859a9223d00a2',
#    'commits': [{'sha': 'f5e8bbe91a544a26f5179a40a906e4ea0a88df9a',
#      'author': {'email': '58213711+iplcdn@users.noreply.github.com',
#       'name': 'iplcdn'},
#      'message': 'Create jd_crazy_joy.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/iplcdn/Actions-scripts/commits/f5e8bbe91a544a26f5179a40a906e4ea0a88df9a'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915592',
#   'type': 'PushEvent',
#   'actor': {'id': 47688611,
#    'login': 'kws02352',
#    'display_login': 'kws02352',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kws02352',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47688611?'},
#   'repo': {'id': 330833958,
#    'name': 'kws02352/study',
#    'url': 'https://api.github.com/repos/kws02352/study'},
#   'payload': {'push_id': 6459679008,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '9f32a679d02c06bd5281486928defe2812f7c6a0',
#    'before': '044a50e8299d3f9cdfdafead0f9d107e4c499255',
#    'commits': [{'sha': '9f32a679d02c06bd5281486928defe2812f7c6a0',
#      'author': {'email': '47688611+kws02352@users.noreply.github.com',
#       'name': 'kws02352'},
#      'message': 'Update Optimization.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kws02352/study/commits/9f32a679d02c06bd5281486928defe2812f7c6a0'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915590',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 3961425,
#    'name': 'easydigitaldownloads/easy-digital-downloads',
#    'url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads/issues/8061',
#     'repository_url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads',
#     'labels_url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads/issues/8061/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads/issues/8061/comments',
#     'events_url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads/issues/8061/events',
#     'html_url': 'https://github.com/easydigitaldownloads/easy-digital-downloads/pull/8061',
#     'id': 657792986,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDQ5ODUxNTg0',
#     'number': 8061,
#     'title': 'Bump lodash from 4.17.14 to 4.17.19',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 1376082103,
#       'node_id': 'MDU6TGFiZWwxMzc2MDgyMTAz',
#       'url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads/labels/scope-dependency',
#       'name': 'scope-dependency',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2020-07-16T02:30:12Z',
#     'updated_at': '2021-02-02T14:41:04Z',
#     'closed_at': '2021-02-02T14:41:02Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads/pulls/8061',
#      'html_url': 'https://github.com/easydigitaldownloads/easy-digital-downloads/pull/8061',
#      'diff_url': 'https://github.com/easydigitaldownloads/easy-digital-downloads/pull/8061.diff',
#      'patch_url': 'https://github.com/easydigitaldownloads/easy-digital-downloads/pull/8061.patch'},
#     'body': 'Bumps [lodash](https://github.com/lodash/lodash) from 4.17.14 to 4.17.19.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/lodash/lodash/releases">lodash\'s releases</a>.</em></p>\n<blockquote>\n<h2>4.17.16</h2>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/lodash/lodash/commit/d7fbc52ee0466a6d248f047b5d5c3e6d1e099056"><code>d7fbc52</code></a> Bump to v4.17.19</li>\n<li><a href="https://github.com/lodash/lodash/commit/2e1c0f22f425e9c013815b2cd7c2ebd51f49a8d6"><code>2e1c0f2</code></a> Add npm-package</li>\n<li><a href="https://github.com/lodash/lodash/commit/1b6c282299f4e0271f932b466c67f0f822aa308e"><code>1b6c282</code></a> Bump to v4.17.18</li>\n<li><a href="https://github.com/lodash/lodash/commit/a370ac81408de2da77a82b3c4b61a01a3b9c2fac"><code>a370ac8</code></a> Bump to v4.17.17</li>\n<li><a href="https://github.com/lodash/lodash/commit/1144918f3578a84fcc4986da9b806e63a6175cbb"><code>1144918</code></a> Rebuild lodash and docs</li>\n<li><a href="https://github.com/lodash/lodash/commit/3a3b0fd339c2109563f7e8167dc95265ed82ef3e"><code>3a3b0fd</code></a> Bump to v4.17.16</li>\n<li><a href="https://github.com/lodash/lodash/commit/c84fe82760fb2d3e03a63379b297a1cc1a2fce12"><code>c84fe82</code></a> fix(zipObjectDeep): prototype pollution (<a href="https://github-redirect.dependabot.com/lodash/lodash/issues/4759">#4759</a>)</li>\n<li><a href="https://github.com/lodash/lodash/commit/e7b28ea6cb17b4ca021e7c9d66218c8c89782f32"><code>e7b28ea</code></a> Sanitize sourceURL so it cannot affect evaled code (<a href="https://github-redirect.dependabot.com/lodash/lodash/issues/4518">#4518</a>)</li>\n<li><a href="https://github.com/lodash/lodash/commit/0cec225778d4ac26c2bac95031ecc92a94f08bbb"><code>0cec225</code></a> Fix lodash.isEqual for circular references (<a href="https://github-redirect.dependabot.com/lodash/lodash/issues/4320">#4320</a>) (<a href="https://github-redirect.dependabot.com/lodash/lodash/issues/4515">#4515</a>)</li>\n<li><a href="https://github.com/lodash/lodash/commit/94c3a8133cb4fcdb50db72b4fd14dd884b195cd5"><code>94c3a81</code></a> Document matches* shorthands for over* methods (<a href="https://github-redirect.dependabot.com/lodash/lodash/issues/4510">#4510</a>) (<a href="https://github-redirect.dependabot.com/lodash/lodash/issues/4514">#4514</a>)</li>\n<li>Additional commits viewable in <a href="https://github.com/lodash/lodash/compare/4.17.14...4.17.19">compare view</a></li>\n</ul>\n</details>\n<details>\n<summary>Maintainer changes</summary>\n<p>This version was pushed to npm by <a href="https://www.npmjs.com/~mathias">mathias</a>, a new releaser for lodash since your current version.</p>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://dependabot-badges.githubapp.com/badges/compatibility_score?dependency-name=lodash&package-manager=npm_and_yarn&previous-version=4.17.14&new-version=4.17.19)](https://help.github.com/articles/configuring-automated-security-fixes)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the sam ...
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads/issues/comments/771681475',
#     'html_url': 'https://github.com/easydigitaldownloads/easy-digital-downloads/pull/8061#issuecomment-771681475',
#     'issue_url': 'https://api.github.com/repos/easydigitaldownloads/easy-digital-downloads/issues/8061',
#     'id': 771681475,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDc3MTY4MTQ3NQ==',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2021-02-02T14:41:04Z',
#     'updated_at': '2021-02-02T14:41:04Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "OK, I won't notify you again about this release, but will get in touch when a new version is available. If you'd rather skip all updates until the next major or minor version, let me know by commenting `@dependabot ignore this major version` or `@dependabot ignore this minor version`.\n\nIf you change your mind, just re-open this PR and I'll resolve any conflicts on it.",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z',
#   'org': {'id': 2955346,
#    'login': 'easydigitaldownloads',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/easydigitaldownloads',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2955346?'}},
#  {'id': '15035915571',
#   'type': 'PushEvent',
#   'actor': {'id': 54782450,
#    'login': 'cb4rros',
#    'display_login': 'cb4rros',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cb4rros',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54782450?'},
#   'repo': {'id': 208157401,
#    'name': 'cb4rros/Simulation-and-animation-of-a-rocket-launch-similar-to-Falcon-Heavy-Python-minigame.',
#    'url': 'https://api.github.com/repos/cb4rros/Simulation-and-animation-of-a-rocket-launch-similar-to-Falcon-Heavy-Python-minigame.'},
#   'payload': {'push_id': 6459678995,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7a412571aa3e5de1f62530da7cc92892db043d13',
#    'before': 'd61f5052443e7efdb8a3c5026066864562c5d312',
#    'commits': [{'sha': '7a412571aa3e5de1f62530da7cc92892db043d13',
#      'author': {'email': '54782450+cb4rros@users.noreply.github.com',
#       'name': 'Caio Barros'},
#      'message': 'Delete POO.rar',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/cb4rros/Simulation-and-animation-of-a-rocket-launch-similar-to-Falcon-Heavy-Python-minigame./commits/7a412571aa3e5de1f62530da7cc92892db043d13'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915551',
#   'type': 'PushEvent',
#   'actor': {'id': 11394046,
#    'login': 'pbaffiliate10',
#    'display_login': 'pbaffiliate10',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pbaffiliate10',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/11394046?'},
#   'repo': {'id': 194866743,
#    'name': 'pbaffiliate10/repoTestCheckout',
#    'url': 'https://api.github.com/repos/pbaffiliate10/repoTestCheckout'},
#   'payload': {'push_id': 6459678982,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'f9d55bf5c392c2044bbc930ff696bf4c9bae4cff',
#    'before': 'd05cfaa91054754d910cb8f51828732ffc5769c7',
#    'commits': [{'sha': 'f9d55bf5c392c2044bbc930ff696bf4c9bae4cff',
#      'author': {'email': 'pbaffiliate10@gmail.com', 'name': 'pbaffiliate10'},
#      'message': 'Commit from Test -  src/dummyScript',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/pbaffiliate10/repoTestCheckout/commits/f9d55bf5c392c2044bbc930ff696bf4c9bae4cff'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915558',
#   'type': 'CreateEvent',
#   'actor': {'id': 54922741,
#    'login': 'minhyoung0724',
#    'display_login': 'minhyoung0724',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/minhyoung0724',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/54922741?'},
#   'repo': {'id': 335310929,
#    'name': 'minhyoung0724/cheers',
#    'url': 'https://api.github.com/repos/minhyoung0724/cheers'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'KGC 2020/21 Winter Team Project',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915533',
#   'type': 'PushEvent',
#   'actor': {'id': 66381391,
#    'login': 'saqoah',
#    'display_login': 'saqoah',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/saqoah',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/66381391?'},
#   'repo': {'id': 324771408,
#    'name': 'saqoah/data',
#    'url': 'https://api.github.com/repos/saqoah/data'},
#   'payload': {'push_id': 6459678977,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '14706a3cdcf9c2a97b5a614b21da8e552022e53b',
#    'before': '46839841fd815af90815c645525eb8d31c006f8a',
#    'commits': [{'sha': '14706a3cdcf9c2a97b5a614b21da8e552022e53b',
#      'author': {'email': '66381391+saqoah@users.noreply.github.com',
#       'name': 'hmz'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/saqoah/data/commits/14706a3cdcf9c2a97b5a614b21da8e552022e53b'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915546',
#   'type': 'PushEvent',
#   'actor': {'id': 39054543,
#    'login': 'drx-tn',
#    'display_login': 'drx-tn',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/drx-tn',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39054543?'},
#   'repo': {'id': 132474797,
#    'name': 'drx-tn/drx-tn.github.io',
#    'url': 'https://api.github.com/repos/drx-tn/drx-tn.github.io'},
#   'payload': {'push_id': 6459678978,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '388278a46a0ce957487c7048de864c55c67a3c78',
#    'before': '82dfb955766dcb8083d0e69d2ebaf3746e2463a2',
#    'commits': [{'sha': '388278a46a0ce957487c7048de864c55c67a3c78',
#      'author': {'email': '39054543+drx-tn@users.noreply.github.com',
#       'name': 'drx-tn'},
#      'message': 'MPTabs version 0.1.6',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/drx-tn/drx-tn.github.io/commits/388278a46a0ce957487c7048de864c55c67a3c78'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915538',
#   'type': 'PushEvent',
#   'actor': {'id': 52939,
#    'login': 'okitan',
#    'display_login': 'okitan',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/okitan',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52939?'},
#   'repo': {'id': 158891190,
#    'name': 'okitan/4sq-venue',
#    'url': 'https://api.github.com/repos/okitan/4sq-venue'},
#   'payload': {'push_id': 6459678957,
#    'size': 2,
#    'distinct_size': 1,
#    'ref': 'refs/heads/link-markcity',
#    'head': 'ddae780b7601d22023616c4b4bf537aa5d8b98b2',
#    'before': '33435493a16f78bf26981e048d9cb56d3e703304',
#    'commits': [{'sha': 'c26c89426e5fd0b5de8f250256185849cf268fb3',
#      'author': {'email': 'okitakunio@gmail.com', 'name': 'Kunio Okita'},
#      'message': ':innocent: scraped venue of hikarie (#1248)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/okitan/4sq-venue/commits/c26c89426e5fd0b5de8f250256185849cf268fb3'},
#     {'sha': 'ddae780b7601d22023616c4b4bf537aa5d8b98b2',
#      'author': {'email': 'okitakunio@gmail.com', 'name': 'okitan'},
#      'message': 'merge master',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/okitan/4sq-venue/commits/ddae780b7601d22023616c4b4bf537aa5d8b98b2'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915544',
#   'type': 'CreateEvent',
#   'actor': {'id': 37248424,
#    'login': 'BoroviyOrest',
#    'display_login': 'BoroviyOrest',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BoroviyOrest',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37248424?'},
#   'repo': {'id': 335272409,
#    'name': 'BoroviyOrest/SpanishQuizzesAPI',
#    'url': 'https://api.github.com/repos/BoroviyOrest/SpanishQuizzesAPI'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915526',
#   'type': 'PushEvent',
#   'actor': {'id': 12894930,
#    'login': 'NIGHTDOWN',
#    'display_login': 'NIGHTDOWN',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NIGHTDOWN',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12894930?'},
#   'repo': {'id': 211272949,
#    'name': 'NIGHTDOWN/xs1',
#    'url': 'https://api.github.com/repos/NIGHTDOWN/xs1'},
#   'payload': {'push_id': 6459678967,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '7310e8b42ee61145f57f0c70c2b011a6b9ef8e70',
#    'before': '4b40de08530022641b9e2daf0ff2a90078ca5c18',
#    'commits': [{'sha': '7310e8b42ee61145f57f0c70c2b011a6b9ef8e70',
#      'author': {'email': 'lookstory@lookstory.xyz', 'name': 'lookstory'},
#      'message': '8.1.0结算3.0',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/NIGHTDOWN/xs1/commits/7310e8b42ee61145f57f0c70c2b011a6b9ef8e70'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915529',
#   'type': 'PushEvent',
#   'actor': {'id': 39058799,
#    'login': 'lassond',
#    'display_login': 'lassond',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lassond',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39058799?'},
#   'repo': {'id': 331091214,
#    'name': 'imgspc/tk-config-imgspc',
#    'url': 'https://api.github.com/repos/imgspc/tk-config-imgspc'},
#   'payload': {'push_id': 6459678949,
#    'size': 3,
#    'distinct_size': 2,
#    'ref': 'refs/heads/tw_51-generate_binaries',
#    'head': '7739c25806d20faebefc282127c3870d74a8f3fd',
#    'before': '906aee7cf21ab8e73afb330d6318eaac20a4a892',
#    'commits': [{'sha': 'db6e22cafe287171caa23a1d98f3485b05ac9efa',
#      'author': {'email': 'baptiste.guidoux@imaginary-spaces.com',
#       'name': 'Baptiste Guidoux'},
#      'message': 'Merge pull request #5 from imgspc/FRI-35/add-pmt-to-tk-config-imgspc\n\nFri 35/add pmt to tk config imgspc',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/imgspc/tk-config-imgspc/commits/db6e22cafe287171caa23a1d98f3485b05ac9efa'},
#     {'sha': 'eb509b741959290cf5cf9be8501965d4868dce49',
#      'author': {'email': 'david@imgspc.com', 'name': 'David Lassonde'},
#      'message': '* Added the binaries for the UnrealWriter Plugin\n* Added UnrealMenuItem  + binaries\n* Added a tool to automatically copy the UE plugins to an UE project',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/imgspc/tk-config-imgspc/commits/eb509b741959290cf5cf9be8501965d4868dce49'},
#     {'sha': '7739c25806d20faebefc282127c3870d74a8f3fd',
#      'author': {'email': 'david@imgspc.com', 'name': 'David Lassonde'},
#      'message': 'Polish',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/imgspc/tk-config-imgspc/commits/7739c25806d20faebefc282127c3870d74a8f3fd'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z',
#   'org': {'id': 60239527,
#    'login': 'imgspc',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/imgspc',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60239527?'}},
#  {'id': '15035915512',
#   'type': 'PushEvent',
#   'actor': {'id': 18676695,
#    'login': 'rakeshranjan920',
#    'display_login': 'rakeshranjan920',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rakeshranjan920',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/18676695?'},
#   'repo': {'id': 333543670,
#    'name': 'rakeshranjan920/Newportfolio-2-',
#    'url': 'https://api.github.com/repos/rakeshranjan920/Newportfolio-2-'},
#   'payload': {'push_id': 6459678965,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '451b452948900b7fd1641fb0a04048d2b467b148',
#    'before': 'f5ddb9e10f51cd95b1b0fd53a2db8a038b171743',
#    'commits': [{'sha': '451b452948900b7fd1641fb0a04048d2b467b148',
#      'author': {'email': 'rakeshranjan.iiita@gmail.com',
#       'name': 'Rakesh Ranjan'},
#      'message': 'Add files via upload',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/rakeshranjan920/Newportfolio-2-/commits/451b452948900b7fd1641fb0a04048d2b467b148'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915516',
#   'type': 'IssuesEvent',
#   'actor': {'id': 80144,
#    'login': 'StevenBlack',
#    'display_login': 'StevenBlack',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/StevenBlack',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/80144?'},
#   'repo': {'id': 4008931,
#    'name': 'StevenBlack/hosts',
#    'url': 'https://api.github.com/repos/StevenBlack/hosts'},
#   'payload': {'action': 'closed',
#    'issue': {'url': 'https://api.github.com/repos/StevenBlack/hosts/issues/1521',
#     'repository_url': 'https://api.github.com/repos/StevenBlack/hosts',
#     'labels_url': 'https://api.github.com/repos/StevenBlack/hosts/issues/1521/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/StevenBlack/hosts/issues/1521/comments',
#     'events_url': 'https://api.github.com/repos/StevenBlack/hosts/issues/1521/events',
#     'html_url': 'https://github.com/StevenBlack/hosts/issues/1521',
#     'id': 799028216,
#     'node_id': 'MDU6SXNzdWU3OTkwMjgyMTY=',
#     'number': 1521,
#     'title': 'Please open files.slack.com',
#     'user': {'login': 'ydwis40',
#      'id': 4518503,
#      'node_id': 'MDQ6VXNlcjQ1MTg1MDM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/4518503?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ydwis40',
#      'html_url': 'https://github.com/ydwis40',
#      'followers_url': 'https://api.github.com/users/ydwis40/followers',
#      'following_url': 'https://api.github.com/users/ydwis40/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ydwis40/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ydwis40/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ydwis40/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ydwis40/orgs',
#      'repos_url': 'https://api.github.com/users/ydwis40/repos',
#      'events_url': 'https://api.github.com/users/ydwis40/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ydwis40/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 7,
#     'created_at': '2021-02-02T07:49:56Z',
#     'updated_at': '2021-02-02T14:41:04Z',
#     'closed_at': '2021-02-02T14:41:03Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': "I cannot upload files into my slackapp\r\n\r\nI have follow that's files.slack.com has been added to this hosts files \r\nhttps://raw.githubusercontent.com/StevenBlack/hosts/master/hosts",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915510',
#   'type': 'CreateEvent',
#   'actor': {'id': 19243212,
#    'login': 'mickelsonmichael',
#    'display_login': 'mickelsonmichael',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mickelsonmichael',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/19243212?'},
#   'repo': {'id': 166661639,
#    'name': 'mickelsonmichael/js-snackbar',
#    'url': 'https://api.github.com/repos/mickelsonmichael/js-snackbar'},
#   'payload': {'ref': 'v1.0.1',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'A simple, jQuery free Snackbar (Toast) alert',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915485',
#   'type': 'PushEvent',
#   'actor': {'id': 68417258,
#    'login': 'breakingheatmap',
#    'display_login': 'breakingheatmap',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/breakingheatmap',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68417258?'},
#   'repo': {'id': 280356388,
#    'name': 'breakingheatmap/breakingheatmap',
#    'url': 'https://api.github.com/repos/breakingheatmap/breakingheatmap'},
#   'payload': {'push_id': 6459678945,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '0d9f855ed0089116dbc5fa72d252f8ccec44e4d0',
#    'before': '864c2dac6dd928431716698b92bb1eaead26d29f',
#    'commits': [{'sha': '0d9f855ed0089116dbc5fa72d252f8ccec44e4d0',
#      'author': {'email': 'sudomaze@gmail.com', 'name': 'sudomaze'},
#      'message': '1612276859',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/breakingheatmap/breakingheatmap/commits/0d9f855ed0089116dbc5fa72d252f8ccec44e4d0'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915494',
#   'type': 'IssuesEvent',
#   'actor': {'id': 23497693,
#    'login': 'garimadosar5',
#    'display_login': 'garimadosar5',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/garimadosar5',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23497693?'},
#   'repo': {'id': 172675608,
#    'name': 'avniproject/avni-webapp',
#    'url': 'https://api.github.com/repos/avniproject/avni-webapp'},
#   'payload': {'action': 'opened',
#    'issue': {'url': 'https://api.github.com/repos/avniproject/avni-webapp/issues/573',
#     'repository_url': 'https://api.github.com/repos/avniproject/avni-webapp',
#     'labels_url': 'https://api.github.com/repos/avniproject/avni-webapp/issues/573/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/avniproject/avni-webapp/issues/573/comments',
#     'events_url': 'https://api.github.com/repos/avniproject/avni-webapp/issues/573/events',
#     'html_url': 'https://github.com/avniproject/avni-webapp/issues/573',
#     'id': 799342242,
#     'node_id': 'MDU6SXNzdWU3OTkzNDIyNDI=',
#     'number': 573,
#     'title': '[DEA] Filter Issue.',
#     'user': {'login': 'garimadosar5',
#      'id': 23497693,
#      'node_id': 'MDQ6VXNlcjIzNDk3Njkz',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/23497693?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/garimadosar5',
#      'html_url': 'https://github.com/garimadosar5',
#      'followers_url': 'https://api.github.com/users/garimadosar5/followers',
#      'following_url': 'https://api.github.com/users/garimadosar5/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/garimadosar5/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/garimadosar5/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/garimadosar5/subscriptions',
#      'organizations_url': 'https://api.github.com/users/garimadosar5/orgs',
#      'repos_url': 'https://api.github.com/users/garimadosar5/repos',
#      'events_url': 'https://api.github.com/users/garimadosar5/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/garimadosar5/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2021-02-02T14:41:04Z',
#     'updated_at': '2021-02-02T14:41:04Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'body': '1. Program filter is not available on DEA. On the client, we provide hardcoded program list on myDashboard filter.\n2. Voided subject shows up with all the search result. It should only show up once "Include voided" is selected.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z',
#   'org': {'id': 17980372,
#    'login': 'avniproject',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/avniproject',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/17980372?'}},
#  {'id': '15035915499',
#   'type': 'PublicEvent',
#   'actor': {'id': 26699273,
#    'login': 'kbh0581',
#    'display_login': 'kbh0581',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kbh0581',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26699273?'},
#   'repo': {'id': 326596304,
#    'name': 'kbh0581/spring-web-service',
#    'url': 'https://api.github.com/repos/kbh0581/spring-web-service'},
#   'payload': {},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915487',
#   'type': 'DeleteEvent',
#   'actor': {'id': 78029371,
#    'login': 'AndronovN',
#    'display_login': 'AndronovN',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/AndronovN',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78029371?'},
#   'repo': {'id': 335307193,
#    'name': 'AndronovN/test-opam-repo',
#    'url': 'https://api.github.com/repos/AndronovN/test-opam-repo'},
#   'payload': {'ref': 'user', 'ref_type': 'branch', 'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915480',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 23717796,
#    'login': 'depfu[bot]',
#    'display_login': 'depfu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/depfu[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23717796?'},
#   'repo': {'id': 291841415,
#    'name': 'turkdevops/electron',
#    'url': 'https://api.github.com/repos/turkdevops/electron'},
#   'payload': {'action': 'opened',
#    'number': 117,
#    'pull_request': {'url': 'https://api.github.com/repos/turkdevops/electron/pulls/117',
#     'id': 566001343,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTY2MDAxMzQz',
#     'html_url': 'https://github.com/turkdevops/electron/pull/117',
#     'diff_url': 'https://github.com/turkdevops/electron/pull/117.diff',
#     'patch_url': 'https://github.com/turkdevops/electron/pull/117.patch',
#     'issue_url': 'https://api.github.com/repos/turkdevops/electron/issues/117',
#     'number': 117,
#     'state': 'open',
#     'locked': False,
#     'title': '[js] Update typescript: 4.0.2 → 4.1.3 (minor)',
#     'user': {'login': 'depfu[bot]',
#      'id': 23717796,
#      'node_id': 'MDM6Qm90MjM3MTc3OTY=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/715?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/depfu%5Bbot%5D',
#      'html_url': 'https://github.com/apps/depfu',
#      'followers_url': 'https://api.github.com/users/depfu%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/depfu%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/depfu%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/depfu%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/depfu%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/depfu%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/depfu%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/depfu%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/depfu%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': '\n\n\n\n\nHere is everything you need to know about this update. Please take a good look at what changed and the test results before merging this pull request.\n\n### What changed?\n\n#### ✳️ typescript (4.0.2 → 4.1.3) · [Repo](https://github.com/Microsoft/TypeScript)\n\n\n<details>\n<summary>Release Notes</summary>\n<h4><a href="https://github.com/microsoft/TypeScript/releases/tag/v4.1.2">4.1.2</a></h4>\n\n<blockquote><p>For release notes, check out the <a href="https://devblogs.microsoft.com/typescript/announcing-typescript-4-1">release announcement</a>.</p>\n<p>For the complete list of fixed issues, check out the</p>\n<ul>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%93&amp;q=is%3Aissue+milestone%3A%22TypeScript+4.1.0%22+is%3Aclosed+">fixed issues query for TypeScript v4.1.0 (Beta)</a>.</li>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%93&amp;q=is%3Aissue+milestone%3A%22TypeScript+4.1.1%22+is%3Aclosed+">fixed issues query for TypeScript v4.1.1 (RC)</a>.</li>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%93&amp;q=is%3Aissue+milestone%3A%22TypeScript+4.1.2%22+is%3Aclosed+">fixed issues query for TypeScript v4.1.2 (Stable)</a>.</li>\n</ul>\n<p>Downloads are available on:</p>\n<ul>\n<li><a href="https://www.npmjs.com/package/typescript">npm</a></li>\n<li>\n<a href="https://marketplace.visualstudio.com/items?itemName=TypeScriptTeam.TypeScript-41">Visual Studio 2017/2019</a> (<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/wiki/Updating-TypeScript-in-Visual-Studio-2017">Select new version in project options</a>)</li>\n<li><a href="https://www.nuget.org/packages/Microsoft.TypeScript.MSBuild">NuGet package</a></li>\n</ul></blockquote>\n<h4><a href="https://github.com/microsoft/TypeScript/releases/tag/v4.0.5">4.0.5</a></h4>\n\n<blockquote><p>For release notes, check out the <a href="https://devblogs.microsoft.com/typescript/announcing-typescript-4-0/">release announcement</a>.</p>\n<p>For the complete list of fixed issues, check out the</p>\n<ul>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%93&amp;q=is%3Aissue+milestone%3A%22TypeScript+4.0.0%22+is%3Aclosed+">fixed issues query for TypeScript v4.0.0 (Beta)</a>.</li>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%93&amp;q=is%3Aissue+milestone%3A%22TypeScript+4.0.1%22+is%3Aclosed+">fixed issues query for TypeScript v4.0.1 (RC)</a>.</li>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%93&amp;q=is%3Aissue+milestone%3A%22TypeScript+4.0.2%22+is%3Aclosed+">fixed issues query for TypeScript v4.0.2</a>.</li>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%93&amp;q=milestone%3A%22TypeScript+4.0.3%22+is%3Aclosed+">fixed issues query for TypeScript v4.0.3</a>.</li>\n<li>TypeScript 4.0.4 NOT FOUND</li>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%93&amp;q=milestone%3A%22TypeScript+4.0.5%22+is%3Aclosed+">fixed issues query for TypeScript v4.0.5</a>.</li>\n</ul>\n<p>Downloads are available on:</p>\n<ul>\n<li><a href="https://www.npmjs.com/package/typescript">npm</a></li>\n</ul></blockquote>\n<h4><a href="https://github.com/microsoft/TypeScript/releases/tag/v4.0.3">4.0.3</a></h4>\n\n<blockquote><p>For release notes, check out the <a href="https://devblogs.microsoft.com/typescript/announcing-typescript-4-0/">release announcement</a>.</p>\n<p>For the complete list of fixed issues, check out the</p>\n<ul>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%93&amp;q=is%3Aissue+milestone%3A%22TypeScript+4.0.0%22+is%3Aclosed+">fixed issues query for TypeScript v4.0.0 (Beta)</a>.</li>\n<li>\n<a href="https://bounce.depfu.com/github.com/Microsoft/TypeScript/issues?utf8=%E2%9C%9 ...
#     'created_at': '2021-02-02T14:41:03Z',
#     'updated_at': '2021-02-02T14:41:03Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': None,
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/turkdevops/electron/pulls/117/commits',
#     'review_comments_url': 'https://api.github.com/repos/turkdevops/electron/pulls/117/comments',
#     'review_comment_url': 'https://api.github.com/repos/turkdevops/electron/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/turkdevops/electron/issues/117/comments',
#     'statuses_url': 'https://api.github.com/repos/turkdevops/electron/statuses/f56687fcbeeca3950dd55a5dec02e42b18416a14',
#     'head': {'label': 'turkdevops:depfu/update/yarn/typescript-4.1.3',
#      'ref': 'depfu/update/yarn/typescript-4.1.3',
#      'sha': 'f56687fcbeeca3950dd55a5dec02e42b18416a14',
#      'user': {'login': 'turkdevops',
#       'id': 67343988,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY3MzQzOTg4',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/67343988?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/turkdevops',
#       'html_url': 'https://github.com/turkdevops',
#       'followers_url': 'https://api.github.com/users/turkdevops/followers',
#       'following_url': 'https://api.github.com/users/turkdevops/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/turkdevops/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/turkdevops/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/turkdevops/subscriptions',
#       'organizations_url': 'https://api.github.com/users/turkdevops/orgs',
#       'repos_url': 'https://api.github.com/users/turkdevops/repos',
#       'events_url': 'https://api.github.com/users/turkdevops/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/turkdevops/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 291841415,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyOTE4NDE0MTU=',
#       'name': 'electron',
#       'full_name': 'turkdevops/electron',
#       'private': False,
#       'owner': {'login': 'turkdevops',
#        'id': 67343988,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY3MzQzOTg4',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/67343988?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/turkdevops',
#        'html_url': 'https://github.com/turkdevops',
#        'followers_url': 'https://api.github.com/users/turkdevops/followers',
#        'following_url': 'https://api.github.com/users/turkdevops/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/turkdevops/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/turkdevops/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/turkdevops/subscriptions',
#        'organizations_url': 'https://api.github.com/users/turkdevops/orgs',
#        'repos_url': 'https://api.github.com/users/turkdevops/repos',
#        'events_url': 'https://api.github.com/users/turkdevops/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/turkdevops/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/turkdevops/electron',
#       'description': ':electron: Build cross-platform desktop apps with JavaScript, HTML, and CSS',
#       'fork': True,
#       'url': 'https://api.github.com/repos/turkdevops/electron',
#       'forks_url': 'https://api.github.com/repos/turkdevops/electron/forks',
#       'keys_url': 'https://api.github.com/repos/turkdevops/electron/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/turkdevops/electron/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/turkdevops/electron/teams',
#       'hooks_url': 'https://api.github.com/repos/turkdevops/electron/hooks',
#       'issue_events_url': 'https://api.github.com/repos/turkdevops/electron/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/turkdevops/electron/events',
#       'assignees_url': 'https://api.github.com/repos/turkdevops/electron/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/turkdevops/electron/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/turkdevops/electron/tags',
#       'blobs_url': 'https://api.github.com/repos/turkdevops/electron/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/turkdevops/electron/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/turkdevops/electron/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/turkdevops/electron/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/turkdevops/electron/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/turkdevops/electron/languages',
#       'stargazers_url': 'https://api.github.com/repos/turkdevops/electron/stargazers',
#       'contributors_url': 'https://api.github.com/repos/turkdevops/electron/contributors',
#       'subscribers_url': 'https://api.github.com/repos/turkdevops/electron/subscribers',
#       'subscription_url': 'https://api.github.com/repos/turkdevops/electron/subscription',
#       'commits_url': 'https://api.github.com/repos/turkdevops/electron/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/turkdevops/electron/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/turkdevops/electron/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/turkdevops/electron/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/turkdevops/electron/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/turkdevops/electron/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/turkdevops/electron/merges',
#       'archive_url': 'https://api.github.com/repos/turkdevops/electron/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/turkdevops/electron/downloads',
#       'issues_url': 'https://api.github.com/repos/turkdevops/electron/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/turkdevops/electron/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/turkdevops/electron/milestones{/number}',
# ...
#       'collaborators_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/teams',
#       'hooks_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/hooks',
#       'issue_events_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/events',
#       'assignees_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/tags',
#       'blobs_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/languages',
#       'stargazers_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/stargazers',
#       'contributors_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/contributors',
#       'subscribers_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/subscribers',
#       'subscription_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/subscription',
#       'commits_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/merges',
#       'archive_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/downloads',
#       'issues_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/FabianVolkers/foundations-sample-website-/deployments',
#       'created_at': '2021-01-28T12:32:33Z',
#       'updated_at': '2021-02-02T14:39:44Z',
#       'pushed_at': '2021-02-02T14:39:42Z',
#       'git_url': 'git://github.com/FabianVolkers/foundations-sample-website-.git',
#       'ssh_url': 'git@github.com:FabianVolkers/foundations-sample-website-.git',
#       'clone_url': 'https://github.com/FabianVolkers/foundations-sample-website-.git',
#       'svn_url': 'https://github.com/FabianVolkers/foundations-sample-website-',
#       'homepage': None,
#       'size': 316,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': None,
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     'base': {'label': 'DrAdamRoe:main',
#      'ref': 'main',
#      'sha': '9cb98b25a6f0db76fe6aa05d66c6ccf7f36e9c42',
#      'user': {'login': 'DrAdamRoe',
#       'id': 14364891,
#       'node_id': 'MDQ6VXNlcjE0MzY0ODkx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/14364891?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/DrAdamRoe',
#       'html_url': 'https://github.com/DrAdamRoe',
#       'followers_url': 'https://api.github.com/users/DrAdamRoe/followers',
#       'following_url': 'https://api.github.com/users/DrAdamRoe/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/DrAdamRoe/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/DrAdamRoe/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/DrAdamRoe/subscriptions',
#       'organizations_url': 'https://api.github.com/users/DrAdamRoe/orgs',
#       'repos_url': 'https://api.github.com/users/DrAdamRoe/repos',
#       'events_url': 'https://api.github.com/users/DrAdamRoe/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/DrAdamRoe/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 320045926,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkzMjAwNDU5MjY=',
#       'name': 'foundations-sample-website-',
#       'full_name': 'DrAdamRoe/foundations-sample-website-',
#       'private': False,
#       'owner': {'login': 'DrAdamRoe',
#        'id': 14364891,
#        'node_id': 'MDQ6VXNlcjE0MzY0ODkx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/14364891?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/DrAdamRoe',
#        'html_url': 'https://github.com/DrAdamRoe',
#        'followers_url': 'https://api.github.com/users/DrAdamRoe/followers',
#        'following_url': 'https://api.github.com/users/DrAdamRoe/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/DrAdamRoe/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/DrAdamRoe/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/DrAdamRoe/subscriptions',
#        'organizations_url': 'https://api.github.com/users/DrAdamRoe/orgs',
#        'repos_url': 'https://api.github.com/users/DrAdamRoe/repos',
#        'events_url': 'https://api.github.com/users/DrAdamRoe/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/DrAdamRoe/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/DrAdamRoe/foundations-sample-website-',
#       'description': None,
#       'fork': False,
#       'url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-',
#       'forks_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/forks',
#       'keys_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/teams',
#       'hooks_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/hooks',
#       'issue_events_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/events',
#       'assignees_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/tags',
#       'blobs_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/languages',
#       'stargazers_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/stargazers',
#       'contributors_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/contributors',
#       'subscribers_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/subscribers',
#       'subscription_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/subscription',
#       'commits_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/merges',
#       'archive_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/downloads',
#       'issues_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/deployments',
#       'created_at': '2020-12-09T18:33:19Z',
#       'updated_at': '2021-02-02T11:32:03Z',
#       'pushed_at': '2021-02-02T11:32:00Z',
#       'git_url': 'git://github.com/DrAdamRoe/foundations-sample-website-.git',
#       'ssh_url': 'git@github.com:DrAdamRoe/foundations-sample-website-.git',
#       'clone_url': 'https://github.com/DrAdamRoe/foundations-sample-website-.git',
#       'svn_url': 'https://github.com/DrAdamRoe/foundations-sample-website-',
#       'homepage': None,
#       'size': 308,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 1,
#       'license': None,
#       'forks': 2,
#       'open_issues': 1,
#       'watchers': 0,
#       'default_branch': 'main'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/pulls/1'},
#      'html': {'href': 'https://github.com/DrAdamRoe/foundations-sample-website-/pull/1'},
#      'issue': {'href': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/issues/1'},
#      'comments': {'href': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/issues/1/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/pulls/1/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/pulls/1/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/DrAdamRoe/foundations-sample-website-/statuses/5817eaf2b12832f20cc7dcd183c59eb22e2aac4b'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': True,
#     'commits': 11,
#     'additions': 44,
#     'deletions': 9,
#     'changed_files': 11}},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915456',
#   'type': 'CreateEvent',
#   'actor': {'id': 40391674,
#    'login': 'doutoury',
#    'display_login': 'doutoury',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/doutoury',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/40391674?'},
#   'repo': {'id': 335320042,
#    'name': 'doutoury/face_embedding',
#    'url': 'https://api.github.com/repos/doutoury/face_embedding'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915446',
#   'type': 'PushEvent',
#   'actor': {'id': 74113347,
#    'login': 'commit-b0t',
#    'display_login': 'commit-b0t',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/commit-b0t',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/74113347?'},
#   'repo': {'id': 310908821,
#    'name': 'commit-b0t/commit-b0t',
#    'url': 'https://api.github.com/repos/commit-b0t/commit-b0t'},
#   'payload': {'push_id': 6459678929,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '64d9b894679737f960ac9dc1aa9f7a48444b09f2',
#    'before': 'c54bc4bcb13c75283f1907372fdf293340784e8c',
#    'commits': [{'sha': '64d9b894679737f960ac9dc1aa9f7a48444b09f2',
#      'author': {'email': '74113347+commit-b0t@users.noreply.github.com',
#       'name': 'Commit'},
#      'message': 'chore: updated README.md',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/commit-b0t/commit-b0t/commits/64d9b894679737f960ac9dc1aa9f7a48444b09f2'}]},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'},
#  {'id': '15035915454',
#   'type': 'CreateEvent',
#   'actor': {'id': 35734684,
#    'login': 'trannguyenhoangtien',
#    'display_login': 'trannguyenhoangtien',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/trannguyenhoangtien',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/35734684?'},
#   'repo': {'id': 335320002,
#    'name': 'trannguyenhoangtien/Rock-Paper-Scissors',
#    'url': 'https://api.github.com/repos/trannguyenhoangtien/Rock-Paper-Scissors'},
#   'payload': {'ref': 'master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-02T14:41:04Z'}]

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html_doc, 'html.parser')

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>The Dormouse's story</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
soup.title.string
# Out:
# "The Dormouse's story"

# %%
soup.title.parent.name
# Out:
# 'head'

# %%
soup.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
soup.p['class']
# Out:
# ['title']

# %%
soup.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
soup.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
soup.find(id="link3")
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
print(soup.get_text())
# Out:
# The Dormouse's story
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
import pyglet

# %%
window = pyglet.window.Window()

# %%
label = pyglet.text.Label('Hello, world',
                          font_name='Times New Roman',
                          font_size=36,
                          x=window.width//2, y=window.height//2,
                          anchor_x='center', anchor_y='center')

# %%
@window.event
def on_draw():
    window.clear()
    label.draw()

# %%
window
# Out:
# Win32Window(width=640, height=480)

# %%
pyglet.app.run()

# %%
import scrapy

# %%
scrapy startproject project_name
# Out:
#   File "<ipython-input-63-78abf47e43d9>", line 1
#     scrapy startproject project_name
#                       ^
# SyntaxError: invalid syntax

# %%
import subprocess

# %%
data=subprocess.check_output(['netsh','wlan','show','profiles']).decode('utf-8').split('\n')

# %%
profiles=[i.split(":")[1][1:-1] for i in data if "all User profile" in i]

# %%
for i in profiles:
    results=subprocess.check_output(['netsh','wlan','show','profile',i,'key=clear']).decode('utf-8').split('\n')
    try:
        print("{:<30}| {:<}".format(i,results[0]))
    except IndexError :
        print("{:<30}| {:<}").format(i,"")

# %%
data
# Out:
# ['\r',
#  'Profiles on interface Wi-Fi:\r',
#  '\r',
#  'Group policy profiles (read only)\r',
#  '---------------------------------\r',
#  '    <None>\r',
#  '\r',
#  'User profiles\r',
#  '-------------\r',
#  '    All User Profile     : realme 6\r',
#  '    All User Profile     : SIDDU\r',
#  '    All User Profile     : Gani\r',
#  '    All User Profile     : vivo 1820 2\r',
#  '    All User Profile     : Redmi\r',
#  '    All User Profile     : C101\r',
#  '    All User Profile     : Sunrise-PG1\r',
#  '    All User Profile     : Boc8-UmVkbWlOb3RlNA\r',
#  '    All User Profile     : Turista 3rd Floor\r',
#  '    All User Profile     : vivo 1820\r',
#  '    All User Profile     : Sunrise-PG-Guest\r',
#  '    All User Profile     : GreenBubbles-SF\r',
#  '    All User Profile     : Moto M 4283\r',
#  '\r',
#  '']

# %%
# first we will import the subprocess module
import subprocess

# now we will store the profiles data in "data" variable by 
# running the 1st cmd command using subprocess.check_output
data = subprocess.check_output(['netsh', 'wlan', 'show', 'profiles']).decode('utf-8').split('\n')

# now we will store the profile by converting them to list
profiles = [i.split(":")[1][1:-1] for i in data if "All User Profile" in i]

# using for loop in python we are checking and printing the wifi 
# passwords if they are available using the 2nd cmd command
for i in profiles:
    # running the 2nd cmd command to check passwords
    results = subprocess.check_output(['netsh', 'wlan', 'show', 'profile', i, 'key=clear']).decode('utf-8').split('\n')
    # storing passwords after converting them to list
    results = [b.split(":")[1][1:-1] for b in results if "Key Content" in b]
    # printing the profiles(wifi name) with their passwords using 
    # try and except method 
    try:
        print ("{:<30}|  {:<}".format(i, results[0]))
    except IndexError:
        print ("{:<30}|  {:<}".format(i, ""))
# Out:
# realme 6                      |  Kannur@15
# SIDDU                         |  SIDDUKANNURA
# Gani                          |  12345678
# vivo 1820 2                   |
# Redmi                         |  1234567890
# C101                          |  9687173220
# Sunrise-PG1                   |  ggmqu10536
# Boc8-UmVkbWlOb3RlNA           |
# Turista 3rd Floor             |  turista@301
# vivo 1820                     |  144e7b550477
# Sunrise-PG-Guest              |  ggmqu10536
# GreenBubbles-SF               |  Connect@GBSF
# Moto M 4283                   |  kannur10

# %%
import argparse

# %%
import os

# %%
import sys

# %%
sys.path.append(os.path.join(sys.path[0], "../"))

# %%
from instabot import Bot
parser=argparse.ArgumentParser(add_help=True)
parser.add_argument("username",type=str,help="@nameispreeti")
args=parser.parse_args()
if args.username[0] !="@":
    args.username="@"+ args.username
bot=Bot()
bot=login()
medias=bot.get_total_user_medias(args.username)
bot.download_photos(medias)
# Out:
# usage: ipykernel_launcher.py [-h] username
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
def searchAndOpenProfile(profileName):
    driver.find_element_by_xpath(“//*[@placeholder=’Search’]”).clear()
    driver.find_element_by_xpath(“//*[@placeholder=’Search’]”).send_keys(profileName)
    time.sleep(3)
    screenCap()
    ele=driver.find_element_by_xpath(“//*[@class=’fuqBx’]”)
    results=ele.find_elements_by_tag_name(“a”)
    for i in results:
    if “#” not in i.text:
    i.click()
    print(i.text.partition(‘\n’)[0]+” Profile Opened”)
    plt.show()
    break;
# Out:
#   File "<ipython-input-23-2c436f44ba5d>", line 2
#     driver.find_element_by_xpath(“//*[@placeholder=’Search’]”).clear()
#                                  ^
# SyntaxError: invalid character in identifier

# %%
# Out:
# _StoreAction(option_strings=[], dest='username', nargs=None, const=None, default=None, type=<class 'str'>, choices=None, help='@username', metavar=None)

# %%
# Out:
# usage: ipykernel_launcher.py [-h] username
# ipykernel_launcher.py: error: unrecognized arguments: -f
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
browser = selenium.webdriver('Chrome')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-3c85595ccc1d> in <module>
# ----> 1 browser = selenium.webdriver('Chrome')
#
# NameError: name 'selenium' is not defined
