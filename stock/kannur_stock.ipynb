# %%
from nsepy import get_history
from datetime import date
import pandas as pd

# %%
from nsepy.derivatives import get_expiry_date
expiry = get_expiry_date(year=2015, month=12)
expiry
# Out:
# {datetime.date(2015, 12, 18), datetime.date(2015, 12, 31)}

# %%
tcs = get_history(symbol='TCS',
                   start=date(2019,1,1),
                   end=date(2019,12,31))
infy = get_history(symbol='INFY',
                   start=date(2019,1,1),
                   end=date(2019,12,31))
nifty_it = get_history(symbol="NIFTYIT",
                            start=date(2019,1,1),
                            end=date(2019,12,31),
                            index=True)

# %%
tcs
# Out:
#            Symbol Series  Prev Close    Open     High      Low     Last  \
# Date
# 2019-01-01    TCS     EQ     1893.05  1896.0  1910.00  1885.00  1905.90
# 2019-01-02    TCS     EQ     1902.80  1905.0  1934.45  1900.00  1919.00
# 2019-01-03    TCS     EQ     1923.30  1919.0  1944.95  1893.10  1901.00
# 2019-01-04    TCS     EQ     1899.95  1900.0  1901.20  1841.00  1882.00
# 2019-01-07    TCS     EQ     1876.85  1891.8  1908.80  1881.00  1898.00
# ...           ...    ...         ...     ...      ...      ...      ...
# 2019-12-24    TCS     EQ     2231.70  2239.0  2243.55  2211.15  2216.00
# 2019-12-26    TCS     EQ     2215.60  2216.4  2229.00  2195.20  2202.00
# 2019-12-27    TCS     EQ     2201.95  2208.0  2226.40  2176.00  2209.90
# 2019-12-30    TCS     EQ     2198.50  2207.0  2225.00  2177.10  2183.35
# 2019-12-31    TCS     EQ     2183.20  2189.0  2197.00  2157.45  2165.00
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# ...

# %%
infy
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-01-01   INFY     EQ      658.95  660.95  666.30  654.15  665.95  665.05
# 2019-01-02   INFY     EQ      665.05  666.00  674.00  662.05  668.00  669.05
# 2019-01-03   INFY     EQ      669.05  672.00  677.00  663.10  668.00  669.15
# 2019-01-04   INFY     EQ      669.15  671.75  673.90  651.00  660.25  661.05
# 2019-01-07   INFY     EQ      661.05  665.00  673.60  661.50  671.70  671.70
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2019-12-24   INFY     EQ      736.00  736.95  736.95  728.30  734.25  733.40
# 2019-12-26   INFY     EQ      733.40  732.00  734.55  726.55  729.50  728.95
# 2019-12-27   INFY     EQ      728.95  729.75  737.50  728.85  736.55  736.95
# 2019-12-30   INFY     EQ      736.95  736.10  737.95  727.25  732.50  732.90
# 2019-12-31   INFY     EQ      732.90  729.70  737.75  725.45  732.00  731.15
#
# ...

# %%
nifty_it
# Out:
#                 Open      High       Low     Close      Volume      Turnover
# Date
# 2019-01-01  14426.45  14480.55  14357.05  14450.90  14008384.0  7.192000e+09
# 2019-01-02  14467.40  14593.85  14371.00  14447.10  27024498.0  1.623150e+10
# 2019-01-03  14479.75  14542.30  14276.50  14322.15  25156380.0  1.666520e+10
# 2019-01-04  14332.65  14359.20  13958.85  14146.15  32610951.0  2.333040e+10
# 2019-01-07  14238.05  14316.00  14204.65  14291.50  23053554.0  1.489590e+10
# ...              ...       ...       ...       ...         ...           ...
# 2019-12-24  15877.40  15880.15  15739.45  15778.20  16014503.0  1.570190e+10
# 2019-12-26  15784.45  15806.85  15690.95  15706.45  17848305.0  1.472240e+10
# 2019-12-27  15740.40  15824.15  15657.50  15780.70  16652327.0  1.458890e+10
# 2019-12-30  15801.50  15868.95  15715.10  15775.00  16249651.0  1.400990e+10
# 2019-12-31  15754.05  15775.25  15634.50  15652.40  19595240.0  1.563390e+10
#
# [245 rows x 6 columns]

# %%
tcs.head()
# Out:
#            Symbol Series  Prev Close    Open     High     Low    Last  \
# Date
# 2019-01-01    TCS     EQ     1893.05  1896.0  1910.00  1885.0  1905.9
# 2019-01-02    TCS     EQ     1902.80  1905.0  1934.45  1900.0  1919.0
# 2019-01-03    TCS     EQ     1923.30  1919.0  1944.95  1893.1  1901.0
# 2019-01-04    TCS     EQ     1899.95  1900.0  1901.20  1841.0  1882.0
# 2019-01-07    TCS     EQ     1876.85  1891.8  1908.80  1881.0  1898.0
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# 2019-01-01  1902.80  1899.78  1094883  2.080034e+14   32636
# 2019-01-02  1923.30  1922.90  2100463  4.038986e+14   85488
# 2019-01-03  1899.95  1916.85  2611668  5.006178e+14  144072
# 2019-01-04  1876.85  1869.19  4280862  8.001742e+14  208198
# 2019-01-07  1897.90  1894.04  1856423  3.516135e+14   87327
#
#             Deliverable Volume  %Deliverble
# Date
# 2019-01-01              489139       0.4468
# 2019-01-02              664045       0.3161
# ...

# %%
infy.head()
# Out:
#            Symbol Series  Prev Close    Open   High     Low    Last   Close  \
# Date
# 2019-01-01   INFY     EQ      658.95  660.95  666.3  654.15  665.95  665.05
# 2019-01-02   INFY     EQ      665.05  666.00  674.0  662.05  668.00  669.05
# 2019-01-03   INFY     EQ      669.05  672.00  677.0  663.10  668.00  669.15
# 2019-01-04   INFY     EQ      669.15  671.75  673.9  651.00  660.25  661.05
# 2019-01-07   INFY     EQ      661.05  665.00  673.6  661.50  671.70  671.70
#
#               VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2019-01-01  660.66  2943390  1.944579e+14   45422             1282161
# 2019-01-02  669.97  7416655  4.968963e+14  108094             3880800
# 2019-01-03  669.66  6827249  4.571929e+14  125781             3676359
# 2019-01-04  660.17  7889310  5.208305e+14  187590             3747741
# 2019-01-07  667.51  8046340  5.370974e+14  132736             4711672
#
#             %Deliverble
# Date
# 2019-01-01       0.4356
# ...

# %%
nifty_it.head()
# Out:
#                 Open      High       Low     Close      Volume      Turnover
# Date
# 2019-01-01  14426.45  14480.55  14357.05  14450.90  14008384.0  7.192000e+09
# 2019-01-02  14467.40  14593.85  14371.00  14447.10  27024498.0  1.623150e+10
# 2019-01-03  14479.75  14542.30  14276.50  14322.15  25156380.0  1.666520e+10
# 2019-01-04  14332.65  14359.20  13958.85  14146.15  32610951.0  2.333040e+10
# 2019-01-07  14238.05  14316.00  14204.65  14291.50  23053554.0  1.489590e+10

# %%
#setting index as date
tcs.insert(0, 'Date',  pd.to_datetime(tcs.index,format='%Y-%m-%d') )

# %%
print(type(tcs.index))
print(type(tcs.Date))
tcs.Date.dt
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.series.Series'>

# %%
#setting index as date
infy.insert(0, 'Date',  pd.to_datetime(infy.index,format='%Y-%m-%d') )

# %%
print(type(infy.index))
print(type(infy.Date))
infy.Date.dt
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.series.Series'>

# %%
#setting index as date
nifty_it.insert(0, 'Date',  pd.to_datetime(nifty_it.index,format='%Y-%m-%d') )

# %%
print(type(nifty_it.index))
print(type(nifty_it.Date))
nifty_it.Date.dt
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.series.Series'>

# %%
tcs.to_csv('tcs_stock.csv', encoding='utf-8', index=False)
infy.to_csv('infy_stock.csv', encoding='utf-8', index=False)
nifty_it.to_csv('nifty_it_index.csv', encoding='utf-8', index=False)

# %%
pd.to_datetime('2019-01-1 3:45pm')
# Out:
# Timestamp('2019-01-01 15:45:00')

# %%
from pandas import Timestamp

# %%
Timestamp('2019-01-1 15:45:00')
# Out:
# Timestamp('2019-01-01 15:45:00')

# %%
pd.to_datetime('12/31/2019')
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
Timestamp('2019-12-31 00:00:00')
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime('2019-12-31', dayfirst=True)
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
Timestamp('2019-12-31 00:00:00')
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime(['2019-01-01', '12/31/2019', 'Dec 31, 2019'])
# Out:
# DatetimeIndex(['2019-01-01', '2019-12-31', '2019-12-31'], dtype='datetime64[ns]', freq=None)

# %%
pd.DatetimeIndex(['2019-01-01', '2019-12-31', '2019-12-31'], dtype='datetime64[ns]', freq=None)
# Out:
# DatetimeIndex(['2019-01-01', '2019-12-31', '2019-12-31'], dtype='datetime64[ns]', freq=None)

# %%
opsd_daily = pd.read_csv('tcs_stock.csv')
opsd_daily.shape
# Out:
# (245, 15)

# %%
opsd_daily.head(3)
# Out:
#          Date Symbol Series  Prev Close    Open     High     Low    Last  \
# 0  2019-01-01    TCS     EQ     1893.05  1896.0  1910.00  1885.0  1905.9
# 1  2019-01-02    TCS     EQ     1902.80  1905.0  1934.45  1900.0  1919.0
# 2  2019-01-03    TCS     EQ     1923.30  1919.0  1944.95  1893.1  1901.0
#
#      Close     VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  1902.80  1899.78  1094883  2.080034e+14   32636              489139
# 1  1923.30  1922.90  2100463  4.038986e+14   85488              664045
# 2  1899.95  1916.85  2611668  5.006178e+14  144072             1250117
#
#    %Deliverble
# 0       0.4468
# 1       0.3161
# 2       0.4787

# %%
opsd_daily.tail(3)
# Out:
#            Date Symbol Series  Prev Close    Open    High      Low     Last  \
# 242  2019-12-27    TCS     EQ     2201.95  2208.0  2226.4  2176.00  2209.90
# 243  2019-12-30    TCS     EQ     2198.50  2207.0  2225.0  2177.10  2183.35
# 244  2019-12-31    TCS     EQ     2183.20  2189.0  2197.0  2157.45  2165.00
#
#       Close     VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 242  2198.5  2192.11  2720261  5.963119e+14   93892             1285882
# 243  2183.2  2194.63  2288830  5.023141e+14   84027              935920
# 244  2161.7  2171.67  1909289  4.146355e+14   69597              837101
#
#      %Deliverble
# 242       0.4727
# 243       0.4089
# 244       0.4384

# %%
opsd_daily.dtypes
# Out:
# Date                   object
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                  int64
# Deliverable Volume      int64
# %Deliverble           float64
# dtype: object

# %%
opsd_daily = opsd_daily.set_index('Date')
opsd_daily.head(3)
# Out:
#            Symbol Series  Prev Close    Open     High     Low    Last  \
# Date
# 2019-01-01    TCS     EQ     1893.05  1896.0  1910.00  1885.0  1905.9
# 2019-01-02    TCS     EQ     1902.80  1905.0  1934.45  1900.0  1919.0
# 2019-01-03    TCS     EQ     1923.30  1919.0  1944.95  1893.1  1901.0
#
#               Close     VWAP   Volume      Turnover  Trades  \
# Date
# 2019-01-01  1902.80  1899.78  1094883  2.080034e+14   32636
# 2019-01-02  1923.30  1922.90  2100463  4.038986e+14   85488
# 2019-01-03  1899.95  1916.85  2611668  5.006178e+14  144072
#
#             Deliverable Volume  %Deliverble
# Date
# 2019-01-01              489139       0.4468
# 2019-01-02              664045       0.3161
# 2019-01-03             1250117       0.4787

# %%
opsd_daily.index
# Out:
# Index(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04', '2019-01-07',
#        '2019-01-08', '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-14',
#        ...
#        '2019-12-17', '2019-12-18', '2019-12-19', '2019-12-20', '2019-12-23',
#        '2019-12-24', '2019-12-26', '2019-12-27', '2019-12-30', '2019-12-31'],
#       dtype='object', name='Date', length=245)

# %%
opsd_daily = pd.read_csv('infy_stock.csv', index_col=0, parse_dates=True)

# %%
opsd_daily
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-01-01   INFY     EQ      658.95  660.95  666.30  654.15  665.95  665.05
# 2019-01-02   INFY     EQ      665.05  666.00  674.00  662.05  668.00  669.05
# 2019-01-03   INFY     EQ      669.05  672.00  677.00  663.10  668.00  669.15
# 2019-01-04   INFY     EQ      669.15  671.75  673.90  651.00  660.25  661.05
# 2019-01-07   INFY     EQ      661.05  665.00  673.60  661.50  671.70  671.70
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2019-12-24   INFY     EQ      736.00  736.95  736.95  728.30  734.25  733.40
# 2019-12-26   INFY     EQ      733.40  732.00  734.55  726.55  729.50  728.95
# 2019-12-27   INFY     EQ      728.95  729.75  737.50  728.85  736.55  736.95
# 2019-12-30   INFY     EQ      736.95  736.10  737.95  727.25  732.50  732.90
# 2019-12-31   INFY     EQ      732.90  729.70  737.75  725.45  732.00  731.15
#
# ...

# %%
opsd_daily['Year'] = opsd_daily.index.year
opsd_daily['Month'] = opsd_daily.index.month
opsd_daily['Weekday Name'] = opsd_daily.index.weekday_name
# Display a random sampling of 5 rows
opsd_daily.sample(5, random_state=0)
# Out:
#            Symbol Series  Prev Close    Open   High     Low   Last   Close  \
# Date
# 2019-05-17   INFY     EQ      733.10  733.15  735.8  720.10  724.5  723.90
# 2019-12-20   INFY     EQ      730.85  731.00  735.0  728.25  730.0  731.55
# 2019-04-16   INFY     EQ      727.50  727.90  727.9  714.10  724.0  724.10
# 2019-03-20   INFY     EQ      722.25  727.25  742.3  727.15  737.8  738.95
# 2019-09-26   INFY     EQ      792.65  787.75  797.0  778.10  784.6  782.55
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2019-05-17  725.44   8155948  5.916646e+14  126562             4816902
# 2019-12-20  731.45   7794167  5.701077e+14  131404             4269114
# 2019-04-16  722.40  12524411  9.047647e+14  343101             7260034
# 2019-03-20  737.53  13471173  9.935368e+14  368666             6929551
# 2019-09-26  783.93  18442824  1.445780e+15  178651            13292785
#
#             %Deliverble  Year  Month Weekday Name
# Date
# ...

# %%
opsd_daily.loc['2019-01-01':'2019-12-31']
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-01-01   INFY     EQ      658.95  660.95  666.30  654.15  665.95  665.05
# 2019-01-02   INFY     EQ      665.05  666.00  674.00  662.05  668.00  669.05
# 2019-01-03   INFY     EQ      669.05  672.00  677.00  663.10  668.00  669.15
# 2019-01-04   INFY     EQ      669.15  671.75  673.90  651.00  660.25  661.05
# 2019-01-07   INFY     EQ      661.05  665.00  673.60  661.50  671.70  671.70
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2019-12-24   INFY     EQ      736.00  736.95  736.95  728.30  734.25  733.40
# 2019-12-26   INFY     EQ      733.40  732.00  734.55  726.55  729.50  728.95
# 2019-12-27   INFY     EQ      728.95  729.75  737.50  728.85  736.55  736.95
# 2019-12-30   INFY     EQ      736.95  736.10  737.95  727.25  732.50  732.90
# 2019-12-31   INFY     EQ      732.90  729.70  737.75  725.45  732.00  731.15
#
# ...

# %%
opsd_daily.head(3)
# Out:
#            Symbol Series  Prev Close    Open   High     Low    Last   Close  \
# Date
# 2019-01-01   INFY     EQ      658.95  660.95  666.3  654.15  665.95  665.05
# 2019-01-02   INFY     EQ      665.05  666.00  674.0  662.05  668.00  669.05
# 2019-01-03   INFY     EQ      669.05  672.00  677.0  663.10  668.00  669.15
#
#               VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2019-01-01  660.66  2943390  1.944579e+14   45422             1282161
# 2019-01-02  669.97  7416655  4.968963e+14  108094             3880800
# 2019-01-03  669.66  6827249  4.571929e+14  125781             3676359
#
#             %Deliverble  Year  Month Weekday Name
# Date
# 2019-01-01       0.4356  2019      1      Tuesday
# 2019-01-02       0.5233  2019      1    Wednesday
# 2019-01-03       0.5385  2019      1     Thursday

# %%
opsd_daily.tail(3)
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-12-27   INFY     EQ      728.95  729.75  737.50  728.85  736.55  736.95
# 2019-12-30   INFY     EQ      736.95  736.10  737.95  727.25  732.50  732.90
# 2019-12-31   INFY     EQ      732.90  729.70  737.75  725.45  732.00  731.15
#
#               VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2019-12-27  734.36  3399094  2.496172e+14   65467             1848140
# 2019-12-30  732.53  5368416  3.932522e+14  115398             3267316
# 2019-12-31  732.75  6927885  5.076420e+14  156522             2954104
#
#             %Deliverble  Year  Month Weekday Name
# Date
# 2019-12-27       0.5437  2019     12       Friday
# 2019-12-30       0.6086  2019     12       Monday
# 2019-12-31       0.4264  2019     12      Tuesday

# %%
opsd_daily.dtypes
# Out:
# Symbol                 object
# Series                 object
# Prev Close            float64
# Open                  float64
# High                  float64
# Low                   float64
# Last                  float64
# Close                 float64
# VWAP                  float64
# Volume                  int64
# Turnover              float64
# Trades                  int64
# Deliverable Volume      int64
# %Deliverble           float64
# Year                    int64
# Month                   int64
# Weekday Name           object
# dtype: object

# %%
opsd_daily.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14',
#                ...
#                '2019-12-17', '2019-12-18', '2019-12-19', '2019-12-20',
#                '2019-12-23', '2019-12-24', '2019-12-26', '2019-12-27',
#                '2019-12-30', '2019-12-31'],
#               dtype='datetime64[ns]', name='Date', length=245, freq=None)

# %%
# Add columns with year, month, and weekday name
opsd_daily['Year'] = opsd_daily.index.year
opsd_daily['Month'] = opsd_daily.index.month
opsd_daily['Weekday Name'] = opsd_daily.index.weekday_name
# Display a random sampling of 5 rows
opsd_daily.sample(5, random_state=0)
# Out:
#            Symbol Series  Prev Close    Open   High     Low   Last   Close  \
# Date
# 2019-05-17   INFY     EQ      733.10  733.15  735.8  720.10  724.5  723.90
# 2019-12-20   INFY     EQ      730.85  731.00  735.0  728.25  730.0  731.55
# 2019-04-16   INFY     EQ      727.50  727.90  727.9  714.10  724.0  724.10
# 2019-03-20   INFY     EQ      722.25  727.25  742.3  727.15  737.8  738.95
# 2019-09-26   INFY     EQ      792.65  787.75  797.0  778.10  784.6  782.55
#
#               VWAP    Volume      Turnover  Trades  Deliverable Volume  \
# Date
# 2019-05-17  725.44   8155948  5.916646e+14  126562             4816902
# 2019-12-20  731.45   7794167  5.701077e+14  131404             4269114
# 2019-04-16  722.40  12524411  9.047647e+14  343101             7260034
# 2019-03-20  737.53  13471173  9.935368e+14  368666             6929551
# 2019-09-26  783.93  18442824  1.445780e+15  178651            13292785
#
#             %Deliverble  Year  Month Weekday Name
# Date
# ...

# %%
opsd_daily.loc['2019-01-01']
# Out:
# Symbol                       INFY
# Series                         EQ
# Prev Close                 658.95
# Open                       660.95
# High                        666.3
# Low                        654.15
# Last                       665.95
# Close                      665.05
# VWAP                       660.66
# Volume                    2943390
# Turnover              1.94458e+14
# Trades                      45422
# Deliverable Volume        1282161
# %Deliverble                0.4356
# Year                         2019
# Month                           1
# Weekday Name              Tuesday
# Name: 2019-01-01 00:00:00, dtype: object

# %%
opsd_daily.loc['2019-01-01':'2019-12-31']
# Out:
#            Symbol Series  Prev Close    Open    High     Low    Last   Close  \
# Date
# 2019-01-01   INFY     EQ      658.95  660.95  666.30  654.15  665.95  665.05
# 2019-01-02   INFY     EQ      665.05  666.00  674.00  662.05  668.00  669.05
# 2019-01-03   INFY     EQ      669.05  672.00  677.00  663.10  668.00  669.15
# 2019-01-04   INFY     EQ      669.15  671.75  673.90  651.00  660.25  661.05
# 2019-01-07   INFY     EQ      661.05  665.00  673.60  661.50  671.70  671.70
# ...           ...    ...         ...     ...     ...     ...     ...     ...
# 2019-12-24   INFY     EQ      736.00  736.95  736.95  728.30  734.25  733.40
# 2019-12-26   INFY     EQ      733.40  732.00  734.55  726.55  729.50  728.95
# 2019-12-27   INFY     EQ      728.95  729.75  737.50  728.85  736.55  736.95
# 2019-12-30   INFY     EQ      736.95  736.10  737.95  727.25  732.50  732.90
# 2019-12-31   INFY     EQ      732.90  729.70  737.75  725.45  732.00  731.15
#
# ...

# %%
import matplotlib.pyplot as plt
# Display figures inline in Jupyter notebook

# %%
import seaborn as sns
# Use seaborn style defaults and set the default figure size
sns.set(rc={'figure.figsize':(11, 4)})

# %%
opsd_daily.plot(linewidth=0.5);

# %%
# cols_plot = ['tcs', 'info', 'info_it']
axes = opsd_daily.plot(marker='.', alpha=0.5, linestyle='None', figsize=(11, 9), subplots=True)
for ax in axes:
    ax.set_ylabel('')

# %%
import sys

# %%
current=sys.version

# %%
current
# Out:
# '3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]'

# %%
current
# Out:
# '3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]'
